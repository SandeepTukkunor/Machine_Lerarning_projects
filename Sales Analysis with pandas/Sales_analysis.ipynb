# %%
import numpy as np 
import pandas as pd
import os

# %%
#first read the csv file

df = pd.read_csv("sales data/Sales_April_2019.csv")

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
# combine all 12 month datasets

# %%
#get all the data first  and combine all the data 

files = [file for file in os.listdir("./sales data")]
all_month_data = pd.DataFrame()

for file in files:
    df = pd.read_csv("./sales data/" + file)
    all_month_data =pd.concat([all_month_data, df])
    
    
all_month_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
# now make a saperate file of all the data in single csv
all_month_data.to_csv("all_data.csv", index=False)

# %%
#read the updated file
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
# so before performing the next step, we have to clean the data

df.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %% [markdown]
# ### Clean the data

# %%
### Drop NaN
nan_df = all_data[all_data.isna().any(axis= 1)]
nan_df

all_data = all_data.dropna(how="all")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
# find or and delete it 
all_data = all_data[all_data["Order Date"].str[0:2] != "Or"]

# %%
# convert the columns to correct type
all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"])   #make int 
all_data["Price Each"] = pd.to_numeric(all_data["Price Each"])   # make float

# %% [markdown]
# ### Task-2 Add a month column

# %%
#take first 2 strings of "order Date" column
all_data["Month"] = all_data["Order Date"].str[0:2]
# we will get an error because there are some NaN values 
all_data["Month"] = all_data["Month"].astype("int32")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# ### Task 4 : add a column for city

# %%
def get_city(address):
    return address.split(",")[1]

def get_state(address):
    return address.split(",")[2].split(" ")[1]



all_data["City"] = all_data["Purchase Address"].apply(lambda x: f"{get_city(x)} ({get_state(x)})")

all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month  \
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City
# 0        Dallas (TX)
# 1        Boston (MA)
# 2   Los Angeles (CA)
# 3   Los Angeles (CA)
# 4   Los Angeles (CA)

# %% [markdown]
# # Question 1: what was the best month for sales? How much was earned in each month

# %%
all_data["Sales"] =  all_data["Quantity Ordered"] * all_data["Price Each"]

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month  \
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales
# 0        Dallas (TX)   23.90
# 1        Boston (MA)   99.99
# 2   Los Angeles (CA)  600.00
# 3   Los Angeles (CA)   11.99
# 4   Los Angeles (CA)   11.99

# %%
results = all_data.groupby("Month").sum()

# %% [markdown]
# # december was the best month for sales

# %%
import matplotlib.pyplot as plt

# %%
months = range(1,13)
plt.bar(months, results["Sales"], )
plt.xticks(months)
plt.ylabel("Sales in USD($)")
plt.xlabel("month number")
plt.show()

# %% [markdown]
# #### Task 4: Add a city column

# %% [markdown]
# ### Question2: What US City has highest number of sales

# %%
results = all_data.groupby("City").sum()
results
# Out:
#                      Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
cities = [city for city, df in all_data.groupby("City")]
plt.bar(cities, results["Sales"], )
plt.xticks(cities, rotation= 'vertical', size = 8)
plt.ylabel("Sales in USD($)")
plt.xlabel("US city name")
plt.show()

# %% [markdown]
# ### San Francisco is the best performing city

# %% [markdown]
# # Question 3: What time should be display advertisment to maximize likleyhood of customets Buying product?

# %%
all_data["Order Date"]
# Out:
# 0           04/19/19 08:46
# 1         04-07-2019 22:30
# 2         04-12-2019 14:38
# 3         04-12-2019 14:38
# 4           04/30/19 09:27
# 5           04/29/19 13:03
# 6         04-02-2019 07:46
# 7         04-12-2019 10:58
# 8           04/24/19 10:38
# 9         04-08-2019 14:05
# 10          04/18/19 17:18
# 11          04/15/19 12:18
# 12          04/16/19 19:23
# 13          04/22/19 15:09
# 14          04/19/19 14:29
# 15        04-04-2019 20:30
# 16          04/27/19 18:41
# 17        04-03-2019 19:42
# 18        04-03-2019 19:42
# 19          04/27/19 00:30
# 20          04/28/19 11:42
# 21        04-04-2019 19:25
# 22        04-09-2019 23:35
# 23        04-11-2019 10:23
# 24        04-05-2019 00:35
# 25        04-09-2019 21:38
# 26          04/27/19 12:20
# 27          04/20/19 12:00
# 28          04/24/19 20:39
# 29        04-07-2019 11:31
#                 ...
# 186818      09/05/19 19:00
# 186819      09/25/19 22:01
# 186820      09/29/19 07:00
# 186821      09/16/19 19:21
# 186822      09/19/19 18:03
# 186823      09/27/19 10:52
# 186824      09/26/19 17:21
# 186826      09/25/19 00:13
# 186827      09/19/19 17:34
# 186828      09/02/19 21:29
# 186829      09/12/19 23:43
# 186830      09/18/19 20:18
# 186831      09/24/19 22:16
# 186832      09/07/19 20:09
# 186833      09/14/19 19:30
# 186834      09/10/19 23:33
# 186835      09/21/19 23:12
# 186836      09/29/19 17:24
# 186837      09/26/19 10:12
# 186838      09/30/19 21:03
# 186839      09/01/19 22:14
# 186840      09/30/19 13:49
# 186841      09/30/19 13:49
# 186842      09/01/19 19:43
# 186843      09/07/19 15:49
# 186844      09/17/19 20:56
# 186845      09/01/19 16:00
# 186846      09/23/19 07:39
# 186847      09/19/19 17:30
# 186848      09/30/19 00:18
# Name: Order Date, Length: 185950, dtype: object

# %%
all_data["Order Date"] = pd.to_datetime(all_data["Order Date"])

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales
# 0        Dallas (TX)   23.90
# 1        Boston (MA)   99.99
# 2   Los Angeles (CA)  600.00
# 3   Los Angeles (CA)   11.99
# 4   Los Angeles (CA)   11.99

# %%
#Add a saperate "Hour" column 

all_data["Hour"] = all_data["Order Date"].dt.hour
all_data["Minute"] = all_data["Order Date"].dt.minute

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales  Hour  Minute
# 0        Dallas (TX)   23.90     8      46
# 1        Boston (MA)   99.99    22      30
# 2   Los Angeles (CA)  600.00    14      38
# 3   Los Angeles (CA)   11.99    14      38
# 4   Los Angeles (CA)   11.99     9      27

# %%
hours  = [hour for hour, df in all_data.groupby("Hour")]


plt.plot(hours, all_data.groupby("Hour").count())
plt.xticks(hours)
plt.grid()

# %% [markdown]
# ### Question 4: What products are sold most often sold together.?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales  Hour  Minute
# 0        Dallas (TX)   23.90     8      46
# 1        Boston (MA)   99.99    22      30
# 2   Los Angeles (CA)  600.00    14      38
# 3   Los Angeles (CA)   11.99    14      38
# 4   Los Angeles (CA)   11.99     9      27

# %%
df = all_data[all_data["Order ID"].duplicated(keep = False)]

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 17       176574                Google Phone                 1      600.00
# 18       176574        USB-C Charging Cable                 1       11.95
# 29       176585  Bose SoundSport Headphones                 1       99.99
# 30       176585  Bose SoundSport Headphones                 1       99.99
# 31       176586      AAA Batteries (4-pack)                 2        2.99
# 32       176586                Google Phone                 1      600.00
# 118      176672    Lightning Charging Cable                 1       14.95
# 119      176672        USB-C Charging Cable                 1       11.95
# 128      176681    Apple Airpods Headphones                 1      150.00
# 129      176681             ThinkPad Laptop                 1      999.99
# 137      176689  Bose SoundSport Headphones                 1       99.99
# 138      176689      AAA Batteries (4-pack)                 2        2.99
# 188      176739      34in Ultrawide Monitor                 1      379.99
# 189      176739                Google Phone                 1      600.00
# 224      176774    Lightning Charging Cable                 1       14.95
# 225      176774        USB-C Charging Cable                 1       11.95
# 232      176781                      iPhone                 1      700.00
# 233      176781    Lightning Charging Cable                 1       14.95
# 249      176797                Google Phone                 1      600.00
# 250      176797  Bose SoundSport Headphones                 1       99.99
# 251      176797            Wired Headphones                 1       11.99
# 259      176805                Google Phone                 1      600.00
# 260      176805        USB-C Charging Cable                 1       11.95
# 263      176808                Google Phone                 1      600.00
# 264      176808            Wired Headphones                 1       11.99
# 269      176813                Google Phone                 1      600.00
# 270      176813            Wired Headphones                 1       11.99
# 393      176935      AAA Batteries (4-pack)                 1        2.99
# ...         ...                         ...               ...         ...
# 186479   259008    Apple Airpods Headphones                 1      150.00
# 186506   259035            27in FHD Monitor                 1      149.99
# 186507   259035            27in FHD Monitor                 1      149.99
# 186540   259068                Google Phone                 1      600.00
# 186541   259068        USB-C Charging Cable                 1       11.95
# 186596   259121                      iPhone                 1      700.00
# 186597   259121            Wired Headphones                 1       11.99
# 186598   259122      AAA Batteries (4-pack)                 2        2.99
# 186599   259122       AA Batteries (4-pack)                 1        3.84
# 186610   259133                      iPhone                 1      700.00
# 186611   259133            Wired Headphones                 1       11.99
# 186683   259204             Vareebadd Phone                 1      400.00
# 186684   259204        USB-C Charging Cable                 1       11.95
# 186688   259208            27in FHD Monitor                 1      149.99
# 186689   259208             ThinkPad Laptop                 1      999.99
# 186752   259270                Google Phone                 1      600.00
# 186753   259270        USB-C Charging Cable                 1       11.95
# 186760   259277                      iPhone                 1      700.00
# 186761   259277            Wired Headphones                 2       11.99
# 186780   259296    Apple Airpods Headphones                 1      150.00
# 186781   259296    Apple Airpods Headphones                 1      150.00
# 186782   259297                      iPhone                 1      700.00
# 186783   259297    Lightning Charging Cable                 1       14.95
# 186784   259297    Lightning Charging Cable                 1       14.95
# 186790   259303      34in Ultrawide Monitor                 1      379.99
# 186791   259303       AA Batteries (4-pack)                 1        3.84
# 186802   259314            Wired Headphones                 1       11.99
# 186803   259314      AAA Batteries (4-pack)                 2        2.99
# 186840   259350                Google Phone                 1      600.00
# 186841   259350        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  Month  \
# 2      2019-04-12 14:38:00     669 Spruce St, Los Angeles, CA 90001      4
# 3      2019-04-12 14:38:00     669 Spruce St, Los Angeles, CA 90001      4
# 17     2019-04-03 19:42:00        20 Hill St, Los Angeles, CA 90001      4
# 18     2019-04-03 19:42:00        20 Hill St, Los Angeles, CA 90001      4
# 29     2019-04-07 11:31:00        823 Highland St, Boston, MA 02215      4
# 30     2019-04-07 11:31:00        823 Highland St, Boston, MA 02215      4
# 31     2019-04-10 17:00:00   365 Center St, San Francisco, CA 94016      4
# 32     2019-04-10 17:00:00   365 Center St, San Francisco, CA 94016      4
# 118    2019-04-12 11:07:00    778 Maple St, New York City, NY 10001      4
# 119    2019-04-12 11:07:00    778 Maple St, New York City, NY 10001      4
# 128    2019-04-20 10:39:00         331 Cherry St, Seattle, WA 98101      4
# 129    2019-04-20 10:39:00         331 Cherry St, Seattle, WA 98101      4
# 137    2019-04-24 17:15:00  659 Lincoln St, New York City, NY 10001      4
# 138    2019-04-24 17:15:00  659 Lincoln St, New York City, NY 10001      4
# 188    2019-04-05 17:38:00             730 6th St, Austin, TX 73301      4
# 189    2019-04-05 17:38:00             730 6th St, Austin, TX 73301      4
# 224    2019-04-25 15:06:00     372 Church St, Los Angeles, CA 90001      4
# 225    2019-04-25 15:06:00     372 Church St, Los Angeles, CA 90001      4
# 232    2019-04-03 07:37:00         976 Hickory St, Dallas, TX 75001      4
# 233    2019-04-03 07:37:00         976 Hickory St, Dallas, TX 75001      4
# 249    2019-04-21 08:54:00        923 Elm St, Los Angeles, CA 90001      4
# 250    2019-04-21 08:54:00        923 Elm St, Los Angeles, CA 90001      4
# 251    2019-04-21 08:54:00        923 Elm St, Los Angeles, CA 90001      4
# 259    2019-04-01 15:50:00        91 Lincoln St, Portland, OR 97035      4
# 260    2019-04-01 15:50:00        91 Lincoln St, Portland, OR 97035      4
# 263    2019-04-28 18:03:00   933 Meadow St, San Francisco, CA 94016      4
# 264    2019-04-28 18:03:00   933 Meadow St, San Francisco, CA 94016      4
# 269    2019-04-28 18:01:00           269 Hill St, Atlanta, GA 30301      4
# 270    2019-04-28 18:01:00           269 Hill St, Atlanta, GA 30301      4
# 393    2019-04-03 21:31:00             315 1st St, Dallas, TX 75001      4
# ...                    ...                                      ...    ...
# 186479 2019-09-07 13:31:00         441 Meadow St, Atlanta, GA 30301      9
# 186506 2019-09-29 13:52:00     327 Lake St, San Francisco, CA 94016      9
# 186507 2019-09-29 13:52:00     327 Lake St, San Francisco, CA 94016      9
# 186540 2019-09-10 18:39:00      175 Washington St, Boston, MA 02215      9
# 186541 2019-09-10 18:39:00      175 Washington St, Boston, MA 02215      9
# 186596 2019-09-08 22:48:00          190 Meadow St, Austin, TX 73301      9
# 186597 2019-09-08 22:48:00          190 Meadow St, Austin, TX 73301      9
# 186598 2019-09-08 21:15:00         764 Hickory St, Boston, MA 02215      9
# 186599 2019-09-08 21:15:00         764 Hickory St, Boston, MA 02215      9
# 186610 2019-09-01 12:54:00          507 Church St, Boston, MA 02215      9
# 186611 2019-09-01 12:54:00          507 Church St, Boston, MA 02215      9
# 186683 2019-09-17 18:06:00          850 Meadow St, Boston, MA 02215      9
# 186684 2019-09-17 18:06:00          850 Meadow St, Boston, MA 02215      9
# 186688 2019-09-20 14:31:00     375 Pine St, New York City, NY 10001      9
# 186689 2019-09-20 14:31:00     375 Pine St, New York City, NY 10001      9
# 186752 2019-09-06 15:27:00     940 10th St, San Francisco, CA 94016      9
# 186753 2019-09-06 15:27:00     940 10th St, San Francisco, CA 94016      9
# 186760 2019-09-28 13:07:00   795 Willow St, New York City, NY 10001      9
# 186761 2019-09-28 13:07:00   795 Willow St, New York City, NY 10001      9
# 186780 2019-09-28 16:48:00             894 6th St, Dallas, TX 75001      9
# 186781 2019-09-28 16:48:00             894 6th St, Dallas, TX 75001      9
# 186782 2019-09-15 18:54:00            138 Main St, Boston, MA 02215      9
# 186783 2019-09-15 18:54:00            138 Main St, Boston, MA 02215      9
# 186784 2019-09-15 18:54:00            138 Main St, Boston, MA 02215      9
# 186790 2019-09-20 20:18:00            106 7th St, Atlanta, GA 30301      9
# 186791 2019-09-20 20:18:00            106 7th St, Atlanta, GA 30301      9
# 186802 2019-09-16 00:25:00       241 Highland St, Atlanta, GA 30301      9
# 186803 2019-09-16 00:25:00       241 Highland St, Atlanta, GA 30301      9
# 186840 2019-09-30 13:49:00    519 Maple St, San Francisco, CA 94016      9
# 186841 2019-09-30 13:49:00    519 Maple St, San Francisco, CA 94016      9
#
#                        City   Sales  Hour  Minute
# 2          Los Angeles (CA)  600.00    14      38
# 3          Los Angeles (CA)   11.99    14      38
# 17         Los Angeles (CA)  600.00    19      42
# 18         Los Angeles (CA)   11.95    19      42
# 29              Boston (MA)   99.99    11      31
# 30              Boston (MA)   99.99    11      31
# 31       San Francisco (CA)    5.98    17       0
# 32       San Francisco (CA)  600.00    17       0
# 118      New York City (NY)   14.95    11       7
# 119      New York City (NY)   11.95    11       7
# 128            Seattle (WA)  150.00    10      39
# 129            Seattle (WA)  999.99    10      39
# 137      New York City (NY)   99.99    17      15
# 138      New York City (NY)    5.98    17      15
# 188             Austin (TX)  379.99    17      38
# 189             Austin (TX)  600.00    17      38
# 224        Los Angeles (CA)   14.95    15       6
# 225        Los Angeles (CA)   11.95    15       6
# 232             Dallas (TX)  700.00     7      37
# 233             Dallas (TX)   14.95     7      37
# 249        Los Angeles (CA)  600.00     8      54
# 250        Los Angeles (CA)   99.99     8      54
# 251        Los Angeles (CA)   11.99     8      54
# 259           Portland (OR)  600.00    15      50
# 260           Portland (OR)   11.95    15      50
# 263      San Francisco (CA)  600.00    18       3
# 264      San Francisco (CA)   11.99    18       3
# 269            Atlanta (GA)  600.00    18       1
# 270            Atlanta (GA)   11.99    18       1
# 393             Dallas (TX)    2.99    21      31
# ...                     ...     ...   ...     ...
# 186479         Atlanta (GA)  150.00    13      31
# 186506   San Francisco (CA)  149.99    13      52
# 186507   San Francisco (CA)  149.99    13      52
# 186540          Boston (MA)  600.00    18      39
# 186541          Boston (MA)   11.95    18      39
# 186596          Austin (TX)  700.00    22      48
# 186597          Austin (TX)   11.99    22      48
# 186598          Boston (MA)    5.98    21      15
# 186599          Boston (MA)    3.84    21      15
# 186610          Boston (MA)  700.00    12      54
# 186611          Boston (MA)   11.99    12      54
# 186683          Boston (MA)  400.00    18       6
# 186684          Boston (MA)   11.95    18       6
# 186688   New York City (NY)  149.99    14      31
# 186689   New York City (NY)  999.99    14      31
# 186752   San Francisco (CA)  600.00    15      27
# 186753   San Francisco (CA)   11.95    15      27
# 186760   New York City (NY)  700.00    13       7
# 186761   New York City (NY)   23.98    13       7
# 186780          Dallas (TX)  150.00    16      48
# 186781          Dallas (TX)  150.00    16      48
# 186782          Boston (MA)  700.00    18      54
# 186783          Boston (MA)   14.95    18      54
# 186784          Boston (MA)   14.95    18      54
# 186790         Atlanta (GA)  379.99    20      18
# 186791         Atlanta (GA)    3.84    20      18
# 186802         Atlanta (GA)   11.99     0      25
# 186803         Atlanta (GA)    5.98     0      25
# 186840   San Francisco (CA)  600.00    13      49
# 186841   San Francisco (CA)   11.95    13      49
#
# [14649 rows x 11 columns]
